# %%
import os
import json
import pandas as pd
import psycopg2

# %%
#aggregated_insurance in states
path0="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/aggregated/insurance/country/india/state/"
ag_ins_li=os.listdir(path0)

#append data on column for dataframe
col0={"states":[],"year":[],"quarter":[],"transaction_type":[],"transaction_count":[],"transaction_amount":[]}

#for loop for states
for state in ag_ins_li:
    current_states=path0+state+"/"
    ag_year_li=os.listdir(current_states)
#for loop for years   
    for year in ag_year_li:
        current_year=current_states+year+"/"
        ag_json_list=os.listdir(current_year)
#for loop for all files        
        for file in ag_json_list:
            current_file=current_year+file
            data=open(current_file,"r")

#load data in json 
            phonedata0=json.load(data)

#Phonedata dataframe for aggregated transactions
            for i in phonedata0["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                col0["transaction_type"].append(name)
                col0["transaction_count"].append(count)
                col0["transaction_amount"].append(amount)
                col0["states"].append(state)
                col0["year"].append(year)
                col0["quarter"].append(int(file.strip(".json")))

#aggregated_insurance data into dataframe
aggregated_insurance=pd.DataFrame(col0)

#preprocessing
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("-","")
aggregated_insurance["states"]=aggregated_insurance["states"].str.title()
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Andhrapradesh","Andhra Pradesh")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Himachalpradesh","Himachal Pradesh")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Madhyapradesh","Madhya Pradesh")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Tamilnadu","Tamil Nadu")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Uttarpradesh","Uttar Pradesh")
aggregated_insurance["states"]=aggregated_insurance["states"].str.replace("Westbengal","West Bengal")
aggregated_insurance

# %%
aggregated_insurance.states.unique()

# %%
#aggregated transaction in states

path1="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/aggregated/transaction/country/india/state/"
ag_tr_li=os.listdir(path1)

#append data on column for dataframe
col1={"states":[],"year":[],"quarter":[],"transaction_type":[],"transaction_count":[],"transaction_amount":[]}

#for loop for states
for state in ag_tr_li:
    current_states=path1+state+"/"
    ag_year_li=os.listdir(current_states)
#for loop for years   
    for year in ag_year_li:
        current_year=current_states+year+"/"
        ag_json_list=os.listdir(current_year)
#for loop for all files        
        for file in ag_json_list:
            current_file=current_year+file
            data=open(current_file,"r")

#load data in json 
            phonedata=json.load(data)

#Phonedata dataframe for aggregated transactions
            for i in phonedata["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                col1["transaction_type"].append(name)
                col1["transaction_count"].append(count)
                col1["transaction_amount"].append(amount)
                col1["states"].append(state)
                col1["year"].append(year)
                col1["quarter"].append(int(file.strip(".json")))

#aggregated_transaction data into dataframe
aggregated_transaction=pd.DataFrame(col1)

#preprocessing
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("-","")
aggregated_transaction["states"]=aggregated_transaction["states"].str.title()
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Andhrapradesh","Andhra Pradesh")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Himachalpradesh","Himachal Pradesh")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Madhyapradesh","Madhya Pradesh")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Tamilnadu","Tamil Nadu")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Uttarpradesh","Uttar Pradesh")
aggregated_transaction["states"]=aggregated_transaction["states"].str.replace("Westbengal","West Bengal")
aggregated_transaction

# %%
#aggregated users in states

path2="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/aggregated/user/country/india/state/"
ag_user_li=os.listdir(path2)

#append data on column for dataframe
col2={"states":[],"year":[],"quarter":[],"brand":[],"transaction_count":[],"transaction_percentage":[]}

#for loop for states
for state in ag_tr_li:
    current_states=path2+state+"/"
    ag_year_li=os.listdir(current_states)
#for loop for years   
    for year in ag_year_li:
        current_year=current_states+year+"/"
        ag_json_list=os.listdir(current_year)
#for loop for all files        
        for file in ag_json_list:
            current_file=current_year+file
            data=open(current_file,"r")
#load data in json 
            phonedata2 =json.load(data)

#Phonedata dataframe for aggregated transactions
            try:
                for i in phonedata2['data']["usersByDevice"]:
                    brand=i["brand"]
                    count=i["count"]
                    percentage=i["percentage"]
                    col2["brand"].append(brand)
                    col2["transaction_count"].append(count)
                    col2["transaction_percentage"].append(percentage)
                    col2["states"].append(state)
                    col2["year"].append(year)
                    col2["quarter"].append(int(file.strip(".json")))
            except:
                pass

#aggregated_user data into dataframe            
aggregated_user=pd.DataFrame(col2)
#preprocessing
aggregated_user["states"]=aggregated_user["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
aggregated_user["states"]=aggregated_user["states"].str.replace("-","")
aggregated_user["states"]=aggregated_user["states"].str.title()
aggregated_user["states"]=aggregated_user["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
aggregated_user["states"]=aggregated_user["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
aggregated_user["states"]=aggregated_user["states"].str.replace("Andhrapradesh","Andhra Pradesh")
aggregated_user["states"]=aggregated_user["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
aggregated_user["states"]=aggregated_user["states"].str.replace("Himachalpradesh","Himachal Pradesh")
aggregated_user["states"]=aggregated_user["states"].str.replace("Madhyapradesh","Madhya Pradesh")
aggregated_user["states"]=aggregated_user["states"].str.replace("Tamilnadu","Tamil Nadu")
aggregated_user["states"]=aggregated_user["states"].str.replace("Uttarpradesh","Uttar Pradesh")
aggregated_user["states"]=aggregated_user["states"].str.replace("Westbengal","West Bengal")
aggregated_user

# %%
#map_transaction in state
path3="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/map/transaction/hover/country/india/state/"
map_tr_li=os.listdir(path3)

#append data on column for dataframe
col3={"states":[],"year":[],"quarter":[],"district":[],"transaction_count":[],"transaction_amount":[]}

#for loop for states
for state in map_tr_li:
    current_states=path3+state+"/"
    map_year_li=os.listdir(current_states)
#for loop for years   
    for year in map_year_li:
        current_year=current_states+year+"/"
        map_json_list=os.listdir(current_year)
#for loop for all files        
        for file in map_json_list:
            current_file=current_year+file
            data=open(current_file,"r")
#load data in json 
            phonedata3 =json.load(data)
            
#Phonedata dataframe for map transactions
            try:
                for i in phonedata3['data']["hoverDataList"]:
                    name=i["name"]
                    count=i['metric'][0]["count"]
                    amount=i['metric'][0]["amount"]
                    col3["district"].append(name)
                    col3["transaction_count"].append(count)
                    col3["transaction_amount"].append(amount)
                    col3["states"].append(state)
                    col3["year"].append(year)
                    col3["quarter"].append(int(file.strip(".json")))
            except:
                pass

#map_transaction data into dataframe
map_transaction=pd.DataFrame(col3)
map_transaction["states"]=map_transaction["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_transaction["states"]=map_transaction["states"].str.replace("-","")
map_transaction["states"]=map_transaction["states"].str.title()
map_transaction["states"]=map_transaction["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
map_transaction["states"]=map_transaction["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
map_transaction["states"]=map_transaction["states"].str.replace("Andhrapradesh","Andhra Pradesh")
map_transaction["states"]=map_transaction["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
map_transaction["states"]=map_transaction["states"].str.replace("Himachalpradesh","Himachal Pradesh")
map_transaction["states"]=map_transaction["states"].str.replace("Madhyapradesh","Madhya Pradesh")
map_transaction["states"]=map_transaction["states"].str.replace("Tamilnadu","Tamil Nadu")
map_transaction["states"]=map_transaction["states"].str.replace("Uttarpradesh","Uttar Pradesh")
map_transaction["states"]=map_transaction["states"].str.replace("Westbengal","West Bengal")
map_transaction

# %%
 #map_user in state
path4="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/map/user/hover/country/india/state/"
map_user_li=os.listdir(path4)

#append data on column for dataframe
col4={"states":[],"year":[],"quarter":[],"district":[],"registeredUsers":[],"appOpens":[]}

#for loop for states
for state in map_user_li:
    current_states=path4+state+"/"
    map_year_li=os.listdir(current_states)
#for loop for years   
    for year in map_year_li:
        current_year=current_states+year+"/"
        map_json_list=os.listdir(current_year)
#for loop for all files        
        for file in map_json_list:
            current_file=current_year+file
            data=open(current_file,"r")
#load data in json 
            phonedata4 =json.load(data)
            
#Phonedata dataframe for map user
            for i in phonedata4["data"]["hoverData"].items():
                district=i[0]
                registeredUsers=i[1]["registeredUsers"]
                appOpens=i[1]["appOpens"]
                col4["district"].append(district)
                col4["registeredUsers"].append(registeredUsers)
                col4["appOpens"].append(appOpens)
                col4["states"].append(state)
                col4["year"].append(year)
                col4["quarter"].append(int(file.strip(".json")))

#map_user data into dataframe
map_user=pd.DataFrame(col4)
map_user["states"]=map_user["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_user["states"]=map_user["states"].str.replace("-","")
map_user["states"]=map_user["states"].str.title()
map_user["states"]=map_user["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
map_user["states"]=map_user["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
map_user["states"]=map_user["states"].str.replace("Andhrapradesh","Andhra Pradesh")
map_user["states"]=map_user["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
map_user["states"]=map_user["states"].str.replace("Himachalpradesh","Himachal Pradesh")
map_user["states"]=map_user["states"].str.replace("Madhyapradesh","Madhya Pradesh")
map_user["states"]=map_user["states"].str.replace("Tamilnadu","Tamil Nadu")
map_user["states"]=map_user["states"].str.replace("Uttarpradesh","Uttar Pradesh")
map_user["states"]=map_user["states"].str.replace("Westbengal","West Bengal")
map_user

# %%
#map_insurance in state
path5="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/map/insurance/hover/country/india/state/"
map_ins_li=os.listdir(path5)

#append data on column for dataframe
col5={"states":[],"year":[],"quarter":[],"district":[],"transaction_count":[],"transaction_amount":[]}

#for loop for states
for state in map_ins_li:
    current_states=path5+state+"/"
    map_year_li=os.listdir(current_states)
#for loop for years   
    for year in map_year_li:
        current_year=current_states+year+"/"
        map_json_list=os.listdir(current_year)
#for loop for all files        
        for file in map_json_list:
            current_file=current_year+file
            data=open(current_file,"r")
#load data in json 
            phonedata5 =json.load(data)
            
#Phonedata dataframe for map insurance
            try:
                for i in phonedata5['data']["hoverDataList"]:
                    name=i["name"]
                    count=i['metric'][0]["count"]
                    amount=i['metric'][0]["amount"]
                    col5["district"].append(name)
                    col5["transaction_count"].append(count)
                    col5["transaction_amount"].append(amount)
                    col5["states"].append(state)
                    col5["year"].append(year)
                    col5["quarter"].append(int(file.strip(".json")))
            except:
                pass

#map_insurance data into dataframe
map_insurance=pd.DataFrame(col5)
map_insurance["states"]=map_insurance["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_insurance["states"]=map_insurance["states"].str.replace("-","")
map_insurance["states"]=map_insurance["states"].str.title()
map_insurance["states"]=map_insurance["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
map_insurance["states"]=map_insurance["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
map_insurance["states"]=map_insurance["states"].str.replace("Andhrapradesh","Andhra Pradesh")
map_insurance["states"]=map_insurance["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
map_insurance["states"]=map_insurance["states"].str.replace("Himachalpradesh","Himachal Pradesh")
map_insurance["states"]=map_insurance["states"].str.replace("Madhyapradesh","Madhya Pradesh")
map_insurance["states"]=map_insurance["states"].str.replace("Tamilnadu","Tamil Nadu")
map_insurance["states"]=map_insurance["states"].str.replace("Uttarpradesh","Uttar Pradesh")
map_insurance["states"]=map_insurance["states"].str.replace("Westbengal","West Bengal")
map_insurance

# %%
#top_insurance in state
path6="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/top/insurance/country/india/state/"
top_ins_li=os.listdir(path6)

#append data on column for dataframe
col6={"states":[],"year":[],"quarter":[],"pincodes":[],"transaction_count":[],"transaction_amount":[]}

#for loop for states
for state in top_ins_li:
    current_states=path6+state+"/"
    map_year_li=os.listdir(current_states)
#for loop for years   
    for year in map_year_li:
        current_year=current_states+year+"/"
        map_json_list=os.listdir(current_year)
#for loop for all files        
        for file in map_json_list:
            current_file=current_year+file
            data=open(current_file,"r")
#load data in json 
            phonedata6 =json.load(data)
            
#Phonedata dataframe for map insurance
            for i in phonedata6['data']["pincodes"]:
                entityname=i["entityName"]
                count=i['metric']["count"]
                amount=i['metric']["amount"]
                col6["pincodes"].append(entityname)
                col6["transaction_count"].append(count)
                col6["transaction_amount"].append(amount)
                col6["states"].append(state)
                col6["year"].append(year)
                col6["quarter"].append(int(file.strip(".json")))

#top_insurance data into dataframe
top_insurance=pd.DataFrame(col6)
top_insurance["states"]=top_insurance["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_insurance["states"]=top_insurance["states"].str.replace("-","")
top_insurance["states"]=top_insurance["states"].str.title()
top_insurance["states"]=top_insurance["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
top_insurance["states"]=top_insurance["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
top_insurance["states"]=top_insurance["states"].str.replace("Andhrapradesh","Andhra Pradesh")
top_insurance["states"]=top_insurance["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
top_insurance["states"]=top_insurance["states"].str.replace("Himachalpradesh","Himachal Pradesh")
top_insurance["states"]=top_insurance["states"].str.replace("Madhyapradesh","Madhya Pradesh")
top_insurance["states"]=top_insurance["states"].str.replace("Tamilnadu","Tamil Nadu")
top_insurance["states"]=top_insurance["states"].str.replace("Uttarpradesh","Uttar Pradesh")
top_insurance["states"]=top_insurance["states"].str.replace("Westbengal","West Bengal")
top_insurance

# %%
#top_transaction in state
path7="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/top/transaction/country/india/state/"
top_tr_li=os.listdir(path7)

#append data on column for dataframe
col7={"states":[],"year":[],"quarter":[],"pincodes":[],"transaction_count":[],"transaction_amount":[]}

#for loop for states
for state in top_tr_li:
    current_states=path7+state+"/"
    map_year_li=os.listdir(current_states)
#for loop for years   
    for year in map_year_li:
        current_year=current_states+year+"/"
        map_json_list=os.listdir(current_year)
#for loop for all files        
        for file in map_json_list:
            current_file=current_year+file
            data=open(current_file,"r")
#load data in json 
            phonedata7 =json.load(data)
            
#Phonedata dataframe for map transactions
            try:
                for i in phonedata7['data']["pincodes"]:
                    entityname=i["entityName"]
                    count=i['metric']["count"]
                    amount=i['metric']["amount"]
                    col7["pincodes"].append(entityname)
                    col7["transaction_count"].append(count)
                    col7["transaction_amount"].append(amount)
                    col7["states"].append(state)
                    col7["year"].append(year)
                    col7["quarter"].append(int(file.strip(".json")))
            except:
                pass

#map_transaction data into dataframe
top_transaction=pd.DataFrame(col7)
top_transaction["states"]=top_transaction["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_transaction["states"]=top_transaction["states"].str.replace("-","")
top_transaction["states"]=top_transaction["states"].str.title()
top_transaction["states"]=top_transaction["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
top_transaction["states"]=top_transaction["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
top_transaction["states"]=top_transaction["states"].str.replace("Andhrapradesh","Andhra Pradesh")
top_transaction["states"]=top_transaction["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
top_transaction["states"]=top_transaction["states"].str.replace("Himachalpradesh","Himachal Pradesh")
top_transaction["states"]=top_transaction["states"].str.replace("Madhyapradesh","Madhya Pradesh")
top_transaction["states"]=top_transaction["states"].str.replace("Tamilnadu","Tamil Nadu")
top_transaction["states"]=top_transaction["states"].str.replace("Uttarpradesh","Uttar Pradesh")
top_transaction["states"]=top_transaction["states"].str.replace("Westbengal","West Bengal")
top_transaction

# %%
#top_user in state
path8="D:/GUVI/Capstone Project/Phonepe_project/pulse/data/top/user/country/india/state/"
top_user_li=os.listdir(path8)

#append data on column for dataframe
col8={"states":[],"year":[],"quarter":[],"pincodes":[],"registeredUsers":[]}

#for loop for states
for state in top_user_li:
    current_states=path8+state+"/"
    map_year_li=os.listdir(current_states)
#for loop for years   
    for year in map_year_li:
        current_year=current_states+year+"/"
        map_json_list=os.listdir(current_year)
#for loop for all files        
        for file in map_json_list:
            current_file=current_year+file
            data=open(current_file,"r")
#load data in json 
            phonedata8 =json.load(data)
            
#Phonedata dataframe for map user
            for i in phonedata8["data"]["pincodes"]:
                entityname=i["name"]
                registeredUsers=i["registeredUsers"]
                col8["pincodes"].append(entityname)
                col8["registeredUsers"].append(registeredUsers)
                col8["states"].append(state)
                col8["year"].append(year)
                col8["quarter"].append(int(file.strip(".json")))

#map_user data into dataframe
top_user=pd.DataFrame(col8)
top_user["states"]=top_user["states"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_user["states"]=top_user["states"].str.replace("-","")
top_user["states"]=top_user["states"].str.title()
top_user["states"]=top_user["states"].str.replace("Dadra&Nagarhaveli&Daman&Diu","Dadra and Nagar Haveli and Daman and Di")
top_user["states"]=top_user["states"].str.replace("Jammu&Kashmir","Jammu & Kashmir")
top_user["states"]=top_user["states"].str.replace("Andhrapradesh","Andhra Pradesh")
top_user["states"]=top_user["states"].str.replace("Arunachalpradesh","Arunachal Pradesh")
top_user["states"]=top_user["states"].str.replace("Himachalpradesh","Himachal Pradesh")
top_user["states"]=top_user["states"].str.replace("Madhyapradesh","Madhya Pradesh")
top_user["states"]=top_user["states"].str.replace("Tamilnadu","Tamil Nadu")
top_user["states"]=top_user["states"].str.replace("Uttarpradesh","Uttar Pradesh")
top_user["states"]=top_user["states"].str.replace("Westbengal","West Bengal")
top_user

# %%
#Table Creation
#pgsql connection
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        password = "rootroot",
                        database = "Phonepe_db",
                        port = "5432"
                        )
cursor = mydb.cursor()

#aggregated_insurance
cquery_1='''CREATE TABLE if not exists aggregated_insurance(states varchar(255),year int,quarter int,
            transaction_type varchar(255),transaction_count bigint,transaction_amount bigint)'''
cursor.execute(cquery_1)
mydb.commit()

iquery_1=''' INSERT INTO aggregated_insurance(states,year,quarter,transaction_type ,
           transaction_count,transaction_amount )
           
           values(%s,%s,%s,%s,%s,%s)'''

data=aggregated_insurance.values.tolist()
cursor.executemany(iquery_1,data)
mydb.commit()


#aggregated_transaction
cquery_2='''CREATE TABLE if not exists aggregated_transaction(states varchar(255),
            year int,quarter int,transaction_type varchar(255),transaction_count bigint,
            transaction_amount bigint)'''
cursor.execute(cquery_2)
mydb.commit()

iquery_2=''' INSERT INTO aggregated_transaction(states,year,quarter,transaction_type ,
             transaction_count,transaction_amount )
           
             values(%s,%s,%s,%s,%s,%s)'''

data=aggregated_transaction.values.tolist()
cursor.executemany(iquery_2,data)
mydb.commit()

#aggregated_user
cquery_3='''CREATE TABLE if not exists aggregated_user(states varchar(255),
            year int,quarter int,brand varchar(255),transaction_count bigint,
            transaction_percentage float)'''
cursor.execute(cquery_3)
mydb.commit()

iquery_3=''' INSERT INTO aggregated_user(states,year ,quarter,brand, transaction_count,
             transaction_percentage )
           
             values(%s,%s,%s,%s,%s,%s)'''

data=aggregated_user.values.tolist()
cursor.executemany(iquery_3,data)
mydb.commit()

#map_insurance
cquery_4='''CREATE TABLE if not exists map_insurance(states varchar(255),
            year int,quarter int,district varchar(255),transaction_count bigint,
            transaction_amount bigint)'''
cursor.execute(cquery_4)
mydb.commit()

iquery_4=''' INSERT INTO map_insurance(states,year ,quarter,district, transaction_count,
             transaction_amount )
           
             values(%s,%s,%s,%s,%s,%s)'''

data=map_insurance.values.tolist()
cursor.executemany(iquery_4,data)
mydb.commit()

#map_transaction
cquery_5='''CREATE TABLE if not exists map_transaction(states varchar(255),
            year int,quarter int,district varchar(255),transaction_count bigint,
            transaction_amount bigint)'''
cursor.execute(cquery_5)
mydb.commit()

iquery_5=''' INSERT INTO map_transaction(states,year ,quarter,district, transaction_count,
             transaction_amount)
           
             values(%s,%s,%s,%s,%s,%s)'''

data=map_transaction.values.tolist()
cursor.executemany(iquery_5,data)
mydb.commit()

#map_user
cquery_6='''CREATE TABLE if not exists map_user(states varchar(255),
            year int,quarter int,district varchar(255),registeredUsers bigint,
            appOpens bigint)'''
cursor.execute(cquery_6)
mydb.commit()

iquery_6=''' INSERT INTO map_user(states,year ,quarter,district, registeredUsers,appOpens)
           
             values(%s,%s,%s,%s,%s,%s)'''

data=map_user.values.tolist()
cursor.executemany(iquery_6,data)
mydb.commit()

#top_insurance
cquery_7='''CREATE TABLE if not exists top_insurance(states varchar(255),
            year int,quarter int,pincodes int,transaction_count bigint,
            transaction_amount bigint)'''
cursor.execute(cquery_7)
mydb.commit()

iquery_7=''' INSERT INTO top_insurance(states,year ,quarter,pincodes, transaction_count,
             transaction_amount )
           
             values(%s,%s,%s,%s,%s,%s)'''

data=top_insurance.values.tolist()
cursor.executemany(iquery_7,data)
mydb.commit()


#top_transaction
cquery_8='''CREATE TABLE if not exists top_transaction(states varchar(255),
            year int,quarter int,pincodes int,transaction_count bigint,
            transaction_amount bigint)'''
cursor.execute(cquery_8)
mydb.commit()

iquery_8=''' INSERT INTO top_transaction(states,year ,quarter,pincodes, transaction_count,
             transaction_amount)
           
             values(%s,%s,%s,%s,%s,%s)'''

data=top_transaction.values.tolist()
cursor.executemany(iquery_8,data)
mydb.commit()


#top_user
cquery_9='''CREATE TABLE if not exists top_user(states varchar(255),
            year int,quarter int,pincodes int,registeredUsers bigint)'''
cursor.execute(cquery_9)
mydb.commit()

iquery_9=''' INSERT INTO top_user(states,year,quarter,pincodes,registeredUsers)
           
             values(%s,%s,%s,%s,%s)'''

data=top_user.values.tolist()
cursor.executemany(iquery_9,data)
mydb.commit()

# %%
top_user.columns

# %%
aggregated_insurance["year"].unique()
